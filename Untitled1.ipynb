# %%
import numpy
import numpy as np
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#The PLSData function helps to plot the clusters based on the two first features
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.patches as mpatches
def PLSData(X, y, class_labels):

    #the length of the class labels array
    #this array contains the user given names of the classes
    num_labels = len(class_labels)
    
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    
    marker_array = ['o', '^', '*']
    color_array = ['#7C4290', '#A9825B', '#42BE92', '#0066FF']
    cmap_bold = ListedColormap(color_array)


    bnorm = BoundaryNorm(np.arange(0, num_labels + 1, 1), ncolors=num_labels)
    plt.figure()
    
    #plot X, the colors are derived fro the y vector
    plt.scatter(X[:, 0], X[:, 1], s=80, c=y, cmap=cmap_bold, norm = bnorm, alpha = 0.40, edgecolor='black', lw = 1)
    
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    
   #plot the legend of the clusters
    h = []
    for c in range(0, num_labels):
        h.append(mpatches.Patch(color=color_array[c], label=class_labels[c]))
        plt.legend(handles=h)
    
    plt.show()

# %%
#FRUITS CLUSTERING
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

fruits = pd.read_table(r'C:/Users/hazmi/Downloads/fruit_data(1).txt')
Xfp = fruits[['mass','width','height', 'color_score']]
yfp = fruits[['fruit_label']] - 1
Xfn = Xfp.values
yfn = yfp.values

# %%
Xfp[0:5]
# Out:
#    mass  width  height  color_score
# 0   192    8.4     7.3         0.55
# 1   180    8.0     6.8         0.59
# 2   176    7.4     7.2         0.60
# 3    86    6.2     4.7         0.80
# 4    84    6.0     4.6         0.79

# %%
Xfn[0:5]
# Out:
# array([[192.  ,   8.4 ,   7.3 ,   0.55],
#        [180.  ,   8.  ,   6.8 ,   0.59],
#        [176.  ,   7.4 ,   7.2 ,   0.6 ],
#        [ 86.  ,   6.2 ,   4.7 ,   0.8 ],
#        [ 84.  ,   6.  ,   4.6 ,   0.79]])

# %%
yfn[0:6]
# Out:
# array([[0],
#        [0],
#        [0],
#        [1],
#        [1],
#        [1]], dtype=int64)

# %%
y
# Out:
# (100,)

# %%
PLSData(X, y, ['Cluster1', 'Cluster2', 'Cluster3', 'Cluster4'])

# %%
from sklearn.cluster import KMeans
k = 5
km = KMeans(n_clusters = 4)
km.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
km.labels_
# Out:
# array([3, 0, 3, 3, 3, 3, 2, 0, 0, 0, 0, 0, 0, 0, 0, 1, 3, 3, 2, 1, 1, 0,
#        2, 1, 3, 2, 3, 3, 1, 1, 1, 0, 1, 1, 2, 3, 0, 1, 0, 2, 3, 2, 0, 2,
#        2, 0, 1, 2, 3, 2, 3, 1, 2, 2, 2, 0, 0, 1, 1, 0, 0, 1, 1, 3, 1, 0,
#        2, 2, 1, 3, 0, 1, 3, 0, 3, 3, 3, 2, 1, 1, 1, 0, 2, 2, 1, 2, 1, 1,
#        3, 3, 3, 2, 2, 2, 2, 0, 0, 2, 0, 2])

# %% [markdown]
# The silhoutte score is used to assess the clustering performance

# %%
from sklearn.metrics import silhouette_score
#compute silhouette of KMeans clustering
ss = silhouette_score(X, km.labels_, metric='euclidean')
#
# Print the score
#
print('Silhouetter Score: %.3f' % ss)
# Out:
# Silhouetter Score: 0.490

# %%
#compute silhouette of original clustering
ss = silhouette_score(X, y, metric='euclidean')
#
# Print the score
#
print('Silhouetter Score: %.3f' % ss)
# Out:
# Silhouetter Score: 0.412

# %%
PLSData(X, km.labels_, ['Cluster1', 'Cluster2', 'Cluster3', 'Cluster4'])

# %%
km3 = KMeans(n_clusters = 3)
km3.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
#compute silhouette of 3 clusters clustering
ss = silhouette_score(X, km3.labels_, metric='euclidean')
#
# Print the score
#
print('Silhouetter Score: %.3f' % ss)
# Out:
# Silhouetter Score: 0.452

# %%
PLSData(X, km3.labels_, ['Cluster1', 'Cluster2', 'Cluster3'])

# %%
km2 = KMeans(n_clusters = 2)
km2.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
#compute silhouette of 3 clusters clustering
ss = silhouette_score(X, km2.labels_, metric='euclidean')
#
# Print the score
#
print('Silhouetter Score: %.3f' % ss)
# Out:
# Silhouetter Score: 0.444

# %%
PLSData(X, km2.labels_, ['Cluster1', 'Cluster2'])

# %% [markdown]
# FRUITS CLUSTERING

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

fruits = pd.read_table(r'C:/Users/hazmi/Downloads/fruit_data(1).txt')
Xfp = fruits[['mass','width','height', 'color_score']]
yfp = fruits[['fruit_label']] - 1
Xfn = Xfp.values
yfn = yfp.values

# %%
Xfp[0:5]
# Out:
#    mass  width  height  color_score
# 0   192    8.4     7.3         0.55
# 1   180    8.0     6.8         0.59
# 2   176    7.4     7.2         0.60
# 3    86    6.2     4.7         0.80
# 4    84    6.0     4.6         0.79

# %%
Xfn[0:5]
# Out:
# array([[192.  ,   8.4 ,   7.3 ,   0.55],
#        [180.  ,   8.  ,   6.8 ,   0.59],
#        [176.  ,   7.4 ,   7.2 ,   0.6 ],
#        [ 86.  ,   6.2 ,   4.7 ,   0.8 ],
#        [ 84.  ,   6.  ,   4.6 ,   0.79]])

# %%
yfn[0:5]
# Out:
# array([[0],
#        [0],
#        [0],
#        [1],
#        [1]], dtype=int64)

# %%
#we have 4 fruits
np.unique(yfn)
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
#this function plots first feature (mass) in x axis, against second feature (widh) in y axis
PLSData(Xfn, yfn, ['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'])

# %%
scalar = MinMaxScaler().fit(Xfn)
Xfnn = scalar.transform(Xfn)

# %%
Xfnn[0:5]
# Out:
# array([[0.40559441, 0.68421053, 0.50769231, 0.        ],
#        [0.36363636, 0.57894737, 0.43076923, 0.10526316],
#        [0.34965035, 0.42105263, 0.49230769, 0.13157895],
#        [0.03496503, 0.10526316, 0.10769231, 0.65789474],
#        [0.02797203, 0.05263158, 0.09230769, 0.63157895]])

# %%
PLSData(Xfnn, yfn, ['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'])

# %%
kmf = KMeans(n_clusters = 4)
kmf.fit(Xfnn)
# Out:
# KMeans(n_clusters=4)

# %%
#compute silhouette of 3 clusters clustering
ss = silhouette_score(Xfnn, kmf.labels_, metric='euclidean')
#
# Print the score
#
print('Silhouetter Score: %.3f' % ss)
# Out:
# Silhouetter Score: 0.394

# %%
PLSData(Xfnn, kmf.labels_, ['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'])

# %%
kmf = KMeans(n_clusters = 4)
kmf.fit(Xfn)
# Out:
# KMeans(n_clusters=4)

# %%
#compute silhouette of 3 clusters clustering
ss = silhouette_score(Xfn, kmf.labels_, metric='euclidean')
#
# Print the score
#
print('Silhouetter Score: %.3f' % ss)
# Out:
# Silhouetter Score: 0.591

# %%
PLSData(Xfn, kmf.labels_, ['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'])
